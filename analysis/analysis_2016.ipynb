# %% [markdown]
# ### Análise do ano de 2016
#
# Utilizando como base o trabalho descrito em "https://sol.sbc.org.br/index.php/bwaif/article/view/24959", este notebook desenvolverá um alocador de portfólio baseado em aprendizado por reforço, sendo sua performance avaliada ao longo do ano de 2016.

# %%
# Importação do diretório atual de trabalho
import sys
upper_path = sys.path[0][:-8]
sys.path.append(upper_path)

# Importação d0 módulo responsável por criar o banco de dados personalizado
from quantamental_lib import RLDatabase

# Importação de bibliotecas auxiliares
import pandas as pd
import torch

# %%
# Criação dos bancos de dados. Os dados de treino e teste são igualmente distribuídos com base na quantidade máxima de ativos selecionada (30).
rl_db = RLDatabase(end_train = '2015-12-31',end_test='2016-12-31', test_time_window=50)

# Leitura ou criação dos DataFrames de treino e teste
try:
    train_df = pd.read_csv('train_test_dfs/train_2016.csv')
except:
    train_df = rl_db.create_train_database()
    train_df.to_csv('train_test_dfs/train_2016.csv', index=False)

try:
    test_df = pd.read_csv('train_test_dfs/test_2016.csv')
except:
    test_df = rl_db.create_test_database()
    test_df.to_csv('train_test_dfs/test_2016.csv', index=False)

# Universo de tickers disponíveis
br_tickers = train_df.tic.unique()

print(br_tickers)
# Out:
# ['ABEV3' 'B3SA3' 'BBAS3' 'BBDC3' 'BBDC4' 'BRAP4' 'BRFS3' 'CCRO3' 'CMIG4'
#  'CPLE6' 'CSAN3' 'CSNA3' 'CYRE3' 'EQTL3' 'GOAU4' 'ITSA4' 'ITUB4' 'JBSS3'
#  'LREN3' 'PETR3' 'PETR4' 'POMO4' 'RADL3' 'TIMS3' 'USIM5' 'VALE3' 'WEGE3']

# %% [markdown]
# ### Treino do modelo
#
# O ambiente será treinado ao longo de 100 episódios, sendo sua taxa de aprendizado igual a 0.001.

# %%
# Importação do módulo contendo as principais classes necessárias para o treinamento
from quantamental_lib.finRL_POE import *

# Definição das features que serão avaliados pelo modelo
features = ['open', 'high', 'low', 'close', 'volume', 'rsi', 'mom', 'cci', 'stoch',
       'williams', 'macd', 'macd_signal', 'bband', 'USD/BRL', 'IBOV', 'SPX',
       'DJI', 'CDI', 'NASDAQ', 'IPCA', 'SELIC', 'IGPM', 'day']

# %%
# Ambiente de Treino
environment = PortfolioOptimizationEnv(
        train_df,
        initial_amount=100000,
        comission_fee_pct=0,
        time_window=50,
        features=features
    )

# Treinamento do modelo
algo = PG(environment, lr=0.001, portfolio_size = len(br_tickers))
algo.train(episodes=100)

# Salvando o modelo treinado
torch.save(algo.target_policy.state_dict(), "trained_models/policy_EIIE_2016.pt")
# Out:
#   0%|          | 0/100 [00:00<?, ?it/s]
# =================================
# Initial portfolio value:100000
# Final portfolio value: 177287.953125
# Final accumulative portfolio value: 1.77287953125
# Maximum DrawDown: -0.4756537109375
# Sharpe ratio: 0.4573880350079222
# =================================
# =================================
# Initial portfolio value:100000
# Final portfolio value: 184079.03125
# Final accumulative portfolio value: 1.8407903125
# Maximum DrawDown: -0.47353361208669065
# Sharpe ratio: 0.47849520300714027
# =================================
# =================================
# Initial portfolio value:100000
# Final portfolio value: 190663.984375
# Final accumulative portfolio value: 1.90663984375
# Maximum DrawDown: -0.4718478975166114
# Sharpe ratio: 0.4986835249329896
# =================================
# =================================
# Initial portfolio value:100000
# Final portfolio value: 198129.890625
# Final accumulative portfolio value: 1.98129890625
# Maximum DrawDown: -0.47007884112741094
# Sharpe ratio: 0.5208821976966203
# =================================
# =================================
# Initial portfolio value:100000
# Final portfolio value: 208985.234375
# Final accumulative portfolio value: 2.08985234375
# Maximum DrawDown: -0.4676537384817462
# Sharpe ratio: 0.5517213266742901
# =================================
# =================================
# Initial portfolio value:100000
# Final portfolio value: 223712.015625
# Final accumulative portfolio value: 2.23712015625
# Maximum DrawDown: -0.4647376543449785
# Sharpe ratio: 0.591793086895348
# =================================
# =================================
# Initial portfolio value:100000
# Final portfolio value: 245959.515625
# Final accumulative portfolio value: 2.45959515625
# Maximum DrawDown: -0.46095669308461407
# Sharpe ratio: 0.648740553240586
# =================================
# =================================
# Initial portfolio value:100000
# Final portfolio value: 282469.75
# Final accumulative portfolio value: 2.8246975
# Maximum DrawDown: -0.4563908519504445
# Sharpe ratio: 0.7349441119530628
# =================================
# =================================
# Initial portfolio value:100000
# Final portfolio value: 348872.90625
# Final accumulative portfolio value: 3.4887290625
# Maximum DrawDown: -0.4510388075263221
# Sharpe ratio: 0.8716366799225552
# =================================
# =================================
# Initial portfolio value:100000
# Final portfolio value: 443056.78125
# Final accumulative portfolio value: 4.4305678125
# Maximum DrawDown: -0.4458679465851083
# Sharpe ratio: 1.0143200875892662
# =================================
# =================================
# Initial portfolio value:100000
# Final portfolio value: 499465.375
# Final accumulative portfolio value: 4.99465375
# Maximum DrawDown: -0.4465372605384954
# Sharpe ratio: 1.0446611307026556
# =================================
# =================================
# Initial portfolio value:100000
# Final portfolio value: 529141.4375
# Final accumulative portfolio value: 5.291414375
# Maximum DrawDown: -0.44556789575771405
# Sharpe ratio: 1.060089427106423
# =================================
# =================================
# Initial portfolio value:100000
# Final portfolio value: 575941.875
# Final accumulative portfolio value: 5.75941875
# Maximum DrawDown: -0.44100907593731387
# Sharpe ratio: 1.1163272781717364
# =================================
# =================================
# Initial portfolio value:100000
# Final portfolio value: 668472.8125
# Final accumulative portfolio value: 6.684728125
# Maximum DrawDown: -0.4331753953770068
# Sharpe ratio: 1.2124784267635296
# =================================
# =================================
# Initial portfolio value:100000
# Final portfolio value: 828548.75
# Final accumulative portfolio value: 8.2854875
# Maximum DrawDown: -0.4235916030460166
# Sharpe ratio: 1.3305539912186983
# =================================
# =================================
# Initial portfolio value:100000
# Final portfolio value: 1122241.125
# Final accumulative portfolio value: 11.22241125
# Maximum DrawDown: -0.41092322020635175
# Sharpe ratio: 1.4712061691996974
# =================================
# =================================
# Initial portfolio value:100000
# Final portfolio value: 1636598.375
# Final accumulative portfolio value: 16.36598375
# Maximum DrawDown: -0.39448956837262883
# Sharpe ratio: 1.614083449194947
# =================================
# =================================
# Initial portfolio value:100000
# Final portfolio value: 2475563.0
# Final accumulative portfolio value: 24.75563
# Maximum DrawDown: -0.3733429061567768
# Sharpe ratio: 1.7494947439756194
# =================================
# =================================
# Initial portfolio value:100000
# Final portfolio value: 3734606.75
# Final accumulative portfolio value: 37.3460675
# Maximum DrawDown: -0.3482264254065216
# Sharpe ratio: 1.8703474926084418
# =================================
# =================================
# Initial portfolio value:100000
# Final portfolio value: 5521779.0
# Final accumulative portfolio value: 55.21779
# Maximum DrawDown: -0.31904670966365056
# Sharpe ratio: 1.9828511667188529
# =================================
# =================================
# Initial portfolio value:100000
# Final portfolio value: 7926036.5
# Final accumulative portfolio value: 79.260365
# Maximum DrawDown: -0.2907076075010797
# Sharpe ratio: 2.076630355405998
# =================================
# =================================
# Initial portfolio value:100000
# Final portfolio value: 11210392.0
# Final accumulative portfolio value: 112.10392
# Maximum DrawDown: -0.2649227635170467
# Sharpe ratio: 2.1659861338886777
# =================================
# =================================
# Initial portfolio value:100000
# Final portfolio value: 15805516.0
# Final accumulative portfolio value: 158.05516
# Maximum DrawDown: -0.2511111867350446
# Sharpe ratio: 2.2457084284702615
# =================================
# =================================
# Initial portfolio value:100000
# Final portfolio value: 22657702.0
# Final accumulative portfolio value: 226.57702
# Maximum DrawDown: -0.23906811256931504
# Sharpe ratio: 2.323005120193646
# =================================
# =================================
# Initial portfolio value:100000
# Final portfolio value: 32853006.0
# Final accumulative portfolio value: 328.53006
# Maximum DrawDown: -0.23484769963066232
# Sharpe ratio: 2.3769085850624037
# =================================
# =================================
# Initial portfolio value:100000
# Final portfolio value: 48763688.0
# Final accumulative portfolio value: 487.63688
# Maximum DrawDown: -0.2281700444720195
# Sharpe ratio: 2.3992376148803047
# =================================
# =================================
# Initial portfolio value:100000
# Final portfolio value: 70944808.0
# Final accumulative portfolio value: 709.44808
# Maximum DrawDown: -0.2226250725707769
# Sharpe ratio: 2.3810465572821418
# =================================
# =================================
# Initial portfolio value:100000
# Final portfolio value: 102763784.0
# Final accumulative portfolio value: 1027.63784
# Maximum DrawDown: -0.221975265017041
# Sharpe ratio: 2.351112796458193
# =================================
# =================================
# Initial portfolio value:100000
# Final portfolio value: 139596464.0
# Final accumulative portfolio value: 1395.96464
# Maximum DrawDown: -0.21348931219401135
# Sharpe ratio: 2.329406313924793
# =================================
# =================================
# Initial portfolio value:100000
# Final portfolio value: 191263584.0
# Final accumulative portfolio value: 1912.63584
# Maximum DrawDown: -0.21605587856146902
# Sharpe ratio: 2.3222152805169456
# =================================
# =================================
# Initial portfolio value:100000
# Final portfolio value: 250586448.0
# Final accumulative portfolio value: 2505.86448
# Maximum DrawDown: -0.21899478601245626
# Sharpe ratio: 2.3155787461261372
# =================================
# =================================
# Initial portfolio value:100000
# Final portfolio value: 316034528.0
# Final accumulative portfolio value: 3160.34528
# Maximum DrawDown: -0.2264462198019136
# Sharpe ratio: 2.311570408292084
# =================================
# =================================
# Initial portfolio value:100000
# Final portfolio value: 391345664.0
# Final accumulative portfolio value: 3913.45664
# Maximum DrawDown: -0.23152302360744337
# Sharpe ratio: 2.317306654924138
# =================================
# =================================
# Initial portfolio value:100000
# Final portfolio value: 472419712.0
# Final accumulative portfolio value: 4724.19712
# Maximum DrawDown: -0.23604987722187687
# Sharpe ratio: 2.3228813234363774
# =================================
# =================================
# Initial portfolio value:100000
# Final portfolio value: 567817024.0
# Final accumulative portfolio value: 5678.17024
# Maximum DrawDown: -0.2386222417117857
# Sharpe ratio: 2.339499752711384
# =================================
# =================================
# Initial portfolio value:100000
# Final portfolio value: 670130688.0
# Final accumulative portfolio value: 6701.30688
# Maximum DrawDown: -0.241866742386867
# Sharpe ratio: 2.3503894797993556
# =================================
# =================================
# Initial portfolio value:100000
# Final portfolio value: 779431616.0
# Final accumulative portfolio value: 7794.31616
# Maximum DrawDown: -0.24431344906500807
# Sharpe ratio: 2.3664643589103163
# =================================
# =================================
# Initial portfolio value:100000
# Final portfolio value: 913779584.0
# Final accumulative portfolio value: 9137.79584
# Maximum DrawDown: -0.24595413359652374
# Sharpe ratio: 2.3961519702680887
# =================================
# =================================
# Initial portfolio value:100000
# Final portfolio value: 1084239872.0
# Final accumulative portfolio value: 10842.39872
# Maximum DrawDown: -0.24650358548003504
# Sharpe ratio: 2.416465583342829
# =================================
# =================================
# Initial portfolio value:100000
# Final portfolio value: 1246206720.0
# Final accumulative portfolio value: 12462.0672
# Maximum DrawDown: -0.24728868290857886
# Sharpe ratio: 2.4347031851123067
# =================================
# =================================
# Initial portfolio value:100000
# Final portfolio value: 1398820480.0
# Final accumulative portfolio value: 13988.2048
# Maximum DrawDown: -0.2567907537624906
# Sharpe ratio: 2.4490190317060683
# =================================
# =================================
# Initial portfolio value:100000
# Final portfolio value: 1605353216.0
# Final accumulative portfolio value: 16053.53216
# Maximum DrawDown: -0.25881689565479093
# Sharpe ratio: 2.473103854792711
# =================================
# =================================
# Initial portfolio value:100000
# Final portfolio value: 1868984704.0
# Final accumulative portfolio value: 18689.84704
# Maximum DrawDown: -0.26287800248435966
# Sharpe ratio: 2.4932035432480433
# =================================
# =================================
# Initial portfolio value:100000
# Final portfolio value: 2132477696.0
# Final accumulative portfolio value: 21324.77696
# Maximum DrawDown: -0.2664020194733493
# Sharpe ratio: 2.5148867382427795
# =================================
# =================================
# Initial portfolio value:100000
# Final portfolio value: 2431836928.0
# Final accumulative portfolio value: 24318.36928
# Maximum DrawDown: -0.26744979515098266
# Sharpe ratio: 2.53662196593355
# =================================
# =================================
# Initial portfolio value:100000
# Final portfolio value: 2748999680.0
# Final accumulative portfolio value: 27489.9968
# Maximum DrawDown: -0.26812635209181856
# Sharpe ratio: 2.556748763761631
# =================================
# =================================
# Initial portfolio value:100000
# Final portfolio value: 3068284160.0
# Final accumulative portfolio value: 30682.8416
# Maximum DrawDown: -0.2669959748321763
# Sharpe ratio: 2.5756301581184977
# =================================
# =================================
# Initial portfolio value:100000
# Final portfolio value: 3453255424.0
# Final accumulative portfolio value: 34532.55424
# Maximum DrawDown: -0.26918094431341755
# Sharpe ratio: 2.59787278010344
# =================================
# =================================
# Initial portfolio value:100000
# Final portfolio value: 3861507072.0
# Final accumulative portfolio value: 38615.07072
# Maximum DrawDown: -0.26758893048149135
# Sharpe ratio: 2.6166051665393004
# =================================
# =================================
# Initial portfolio value:100000
# Final portfolio value: 4315850752.0
# Final accumulative portfolio value: 43158.50752
# Maximum DrawDown: -0.2659296627745168
# Sharpe ratio: 2.6358954493584976
# =================================
# =================================
# Initial portfolio value:100000
# Final portfolio value: 4771227648.0
# Final accumulative portfolio value: 47712.27648
# Maximum DrawDown: -0.2641913150317651
# Sharpe ratio: 2.6533815630576263
# =================================
# =================================
# Initial portfolio value:100000
# Final portfolio value: 5299752448.0
# Final accumulative portfolio value: 52997.52448
# Maximum DrawDown: -0.26345783207576723
# Sharpe ratio: 2.672797849799525
# =================================
# =================================
# Initial portfolio value:100000
# Final portfolio value: 5823793152.0
# Final accumulative portfolio value: 58237.93152
# Maximum DrawDown: -0.2632826463957897
# Sharpe ratio: 2.687296656089853
# =================================
# =================================
# Initial portfolio value:100000
# Final portfolio value: 6368526336.0
# Final accumulative portfolio value: 63685.26336
# Maximum DrawDown: -0.26101462378929363
# Sharpe ratio: 2.705101985963666
# =================================
# =================================
# Initial portfolio value:100000
# Final portfolio value: 6947842048.0
# Final accumulative portfolio value: 69478.42048
# Maximum DrawDown: -0.2609759761748258
# Sharpe ratio: 2.7219346515915697
# =================================
# =================================
# Initial portfolio value:100000
# Final portfolio value: 7608840192.0
# Final accumulative portfolio value: 76088.40192
# Maximum DrawDown: -0.25970478025157917
# Sharpe ratio: 2.735258835278108
# =================================
# =================================
# Initial portfolio value:100000
# Final portfolio value: 8364674560.0
# Final accumulative portfolio value: 83646.7456
# Maximum DrawDown: -0.2545481341230954
# Sharpe ratio: 2.7504284598685063
# =================================
# =================================
# Initial portfolio value:100000
# Final portfolio value: 8806931456.0
# Final accumulative portfolio value: 88069.31456
# Maximum DrawDown: -0.2548036993425572
# Sharpe ratio: 2.758582562388944
# =================================
# =================================
# Initial portfolio value:100000
# Final portfolio value: 9576545280.0
# Final accumulative portfolio value: 95765.4528
# Maximum DrawDown: -0.2582388563994117
# Sharpe ratio: 2.774875962377642
# =================================
# =================================
# Initial portfolio value:100000
# Final portfolio value: 10454707200.0
# Final accumulative portfolio value: 104547.072
# Maximum DrawDown: -0.259023264110146
# Sharpe ratio: 2.7921632435191213
# =================================
# =================================
# Initial portfolio value:100000
# Final portfolio value: 11203771392.0
# Final accumulative portfolio value: 112037.71392
# Maximum DrawDown: -0.25470409742374356
# Sharpe ratio: 2.802572227232352
# =================================
# =================================
# Initial portfolio value:100000
# Final portfolio value: 11834863616.0
# Final accumulative portfolio value: 118348.63616
# Maximum DrawDown: -0.25560655138645316
# Sharpe ratio: 2.8119017242219697
# =================================
# =================================
# Initial portfolio value:100000
# Final portfolio value: 12793504768.0
# Final accumulative portfolio value: 127935.04768
# Maximum DrawDown: -0.25622339714931197
# Sharpe ratio: 2.8251318936218692
# =================================
# =================================
# Initial portfolio value:100000
# Final portfolio value: 13709349888.0
# Final accumulative portfolio value: 137093.49888
# Maximum DrawDown: -0.25670914431216674
# Sharpe ratio: 2.8369039889039374
# =================================
# =================================
# Initial portfolio value:100000
# Final portfolio value: 14443040768.0
# Final accumulative portfolio value: 144430.40768
# Maximum DrawDown: -0.25721773584294105
# Sharpe ratio: 2.845512800825119
# =================================
# =================================
# Initial portfolio value:100000
# Final portfolio value: 15361567744.0
# Final accumulative portfolio value: 153615.67744
# Maximum DrawDown: -0.2573780403422691
# Sharpe ratio: 2.857506773112646
# =================================
# =================================
# Initial portfolio value:100000
# Final portfolio value: 16353449984.0
# Final accumulative portfolio value: 163534.49984
# Maximum DrawDown: -0.25834635891849234
# Sharpe ratio: 2.866651105464412
# =================================
# =================================
# Initial portfolio value:100000
# Final portfolio value: 17135420416.0
# Final accumulative portfolio value: 171354.20416
# Maximum DrawDown: -0.2587870175733489
# Sharpe ratio: 2.876754164595507
# =================================
# =================================
# Initial portfolio value:100000
# Final portfolio value: 18238210048.0
# Final accumulative portfolio value: 182382.10048
# Maximum DrawDown: -0.2588669787559018
# Sharpe ratio: 2.8873744536450503
# =================================
# =================================
# Initial portfolio value:100000
# Final portfolio value: 19317921792.0
# Final accumulative portfolio value: 193179.21792
# Maximum DrawDown: -0.25900557700358495
# Sharpe ratio: 2.8969470640445016
# =================================
# =================================
# Initial portfolio value:100000
# Final portfolio value: 20189605888.0
# Final accumulative portfolio value: 201896.05888
# Maximum DrawDown: -0.2590418240375789
# Sharpe ratio: 2.9039247037892197
# =================================
# =================================
# Initial portfolio value:100000
# Final portfolio value: 21352761344.0
# Final accumulative portfolio value: 213527.61344
# Maximum DrawDown: -0.25920231140822303
# Sharpe ratio: 2.914496849099767
# =================================
# =================================
# Initial portfolio value:100000
# Final portfolio value: 22464153600.0
# Final accumulative portfolio value: 224641.536
# Maximum DrawDown: -0.2597853223457126
# Sharpe ratio: 2.9207800027559916
# =================================
# =================================
# Initial portfolio value:100000
# Final portfolio value: 23573250048.0
# Final accumulative portfolio value: 235732.50048
# Maximum DrawDown: -0.2596558443963408
# Sharpe ratio: 2.931572009295993
# =================================
# =================================
# Initial portfolio value:100000
# Final portfolio value: 24743280640.0
# Final accumulative portfolio value: 247432.8064
# Maximum DrawDown: -0.2595198703473882
# Sharpe ratio: 2.940846324385031
# =================================
# =================================
# Initial portfolio value:100000
# Final portfolio value: 25931462656.0
# Final accumulative portfolio value: 259314.62656
# Maximum DrawDown: -0.25944355772050864
# Sharpe ratio: 2.949385022591437
# =================================
# =================================
# Initial portfolio value:100000
# Final portfolio value: 27263483904.0
# Final accumulative portfolio value: 272634.83904
# Maximum DrawDown: -0.2596026215606545
# Sharpe ratio: 2.9565522686805203
# =================================
# =================================
# Initial portfolio value:100000
# Final portfolio value: 28538042368.0
# Final accumulative portfolio value: 285380.42368
# Maximum DrawDown: -0.25948354150110997
# Sharpe ratio: 2.964564808070864
# =================================
# =================================
# Initial portfolio value:100000
# Final portfolio value: 29944524800.0
# Final accumulative portfolio value: 299445.248
# Maximum DrawDown: -0.25924801531953046
# Sharpe ratio: 2.97335718802866
# =================================
# =================================
# Initial portfolio value:100000
# Final portfolio value: 31166195712.0
# Final accumulative portfolio value: 311661.95712
# Maximum DrawDown: -0.25890581747077046
# Sharpe ratio: 2.980992754937135
# =================================
# =================================
# Initial portfolio value:100000
# Final portfolio value: 32701534208.0
# Final accumulative portfolio value: 327015.34208
# Maximum DrawDown: -0.2592975327438962
# Sharpe ratio: 2.9877377808169787
# =================================
# =================================
# Initial portfolio value:100000
# Final portfolio value: 33997721600.0
# Final accumulative portfolio value: 339977.216
# Maximum DrawDown: -0.25913509309469185
# Sharpe ratio: 2.996701882875885
# =================================
# =================================
# Initial portfolio value:100000
# Final portfolio value: 35569803264.0
# Final accumulative portfolio value: 355698.03264
# Maximum DrawDown: -0.2586561381966884
# Sharpe ratio: 3.005817407727648
# =================================
# =================================
# Initial portfolio value:100000
# Final portfolio value: 37155274752.0
# Final accumulative portfolio value: 371552.74752
# Maximum DrawDown: -0.25878799234531624
# Sharpe ratio: 3.009221023818645
# =================================
# =================================
# Initial portfolio value:100000
# Final portfolio value: 38698950656.0
# Final accumulative portfolio value: 386989.50656
# Maximum DrawDown: -0.25877530567413043
# Sharpe ratio: 3.018506537084156
# =================================
# =================================
# Initial portfolio value:100000
# Final portfolio value: 40137551872.0
# Final accumulative portfolio value: 401375.51872
# Maximum DrawDown: -0.2586878926700108
# Sharpe ratio: 3.0264524526434964
# =================================
# =================================
# Initial portfolio value:100000
# Final portfolio value: 41828614144.0
# Final accumulative portfolio value: 418286.14144
# Maximum DrawDown: -0.25815790592381616
# Sharpe ratio: 3.033442351347584
# =================================
# =================================
# Initial portfolio value:100000
# Final portfolio value: 43261292544.0
# Final accumulative portfolio value: 432612.92544
# Maximum DrawDown: -0.25835468460828415
# Sharpe ratio: 3.0389282801406545
# =================================
# =================================
# Initial portfolio value:100000
# Final portfolio value: 45122371584.0
# Final accumulative portfolio value: 451223.71584
# Maximum DrawDown: -0.25795509208892053
# Sharpe ratio: 3.0472560014537273
# =================================
# =================================
# Initial portfolio value:100000
# Final portfolio value: 46608691200.0
# Final accumulative portfolio value: 466086.912
# Maximum DrawDown: -0.25797455287091675
# Sharpe ratio: 3.049878376911297
# =================================
# =================================
# Initial portfolio value:100000
# Final portfolio value: 48762728448.0
# Final accumulative portfolio value: 487627.28448
# Maximum DrawDown: -0.25775938829859935
# Sharpe ratio: 3.061051627682298
# =================================
# =================================
# Initial portfolio value:100000
# Final portfolio value: 50113847296.0
# Final accumulative portfolio value: 501138.47296
# Maximum DrawDown: -0.25760555675907115
# Sharpe ratio: 3.0610255073655694
# =================================
# =================================
# Initial portfolio value:100000
# Final portfolio value: 52492091392.0
# Final accumulative portfolio value: 524920.91392
# Maximum DrawDown: -0.25755163453872587
# Sharpe ratio: 3.071635124937573
# =================================
# =================================
# Initial portfolio value:100000
# Final portfolio value: 54195974144.0
# Final accumulative portfolio value: 541959.74144
# Maximum DrawDown: -0.2575493500549533
# Sharpe ratio: 3.076616251071034
# =================================
# =================================
# Initial portfolio value:100000
# Final portfolio value: 56144756736.0
# Final accumulative portfolio value: 561447.56736
# Maximum DrawDown: -0.2574164523386905
# Sharpe ratio: 3.083815514328922
# =================================
# =================================
# Initial portfolio value:100000
# Final portfolio value: 58142154752.0
# Final accumulative portfolio value: 581421.54752
# Maximum DrawDown: -0.2572875983026469
# Sharpe ratio: 3.0909075575510037
# =================================
# =================================
# Initial portfolio value:100000
# Final portfolio value: 60196564992.0
# Final accumulative portfolio value: 601965.64992
# Maximum DrawDown: -0.25700732388221714
# Sharpe ratio: 3.0965062860657873
# =================================
# =================================
# Initial portfolio value:100000
# Final portfolio value: 62062882816.0
# Final accumulative portfolio value: 620628.82816
# Maximum DrawDown: -0.25705632780681964
# Sharpe ratio: 3.103478500899074
# =================================
# =================================
# Initial portfolio value:100000
# Final portfolio value: 64282611712.0
# Final accumulative portfolio value: 642826.11712
# Maximum DrawDown: -0.25663059419010403
# Sharpe ratio: 3.107107612166096
# =================================
# =================================
# Initial portfolio value:100000
# Final portfolio value: 66318204928.0
# Final accumulative portfolio value: 663182.04928
# Maximum DrawDown: -0.2568134022957351
# Sharpe ratio: 3.1145547433523992
# =================================

# %% [markdown]
# ## Teste do modelo
#
# Após o treinamento, será criado um novo ambiente de teste utilizado para a avaliação de sua performance no ano de 2016.

# %%
# Ambiente de teste
environment_test = PortfolioOptimizationEnv(
        test_df,
        initial_amount=100000,
        comission_fee_pct=0,
        time_window=50,
        features=features
    )

# Importação e preparação do modelo treinado
policy = GradientPolicy()
policy.load_state_dict(torch.load("trained_models/policy_EIIE_2016.pt"))
policy = policy.to(device)

# Obtenção das métricas ao longo de 2016
done = False
obs = environment_test.reset()
pvm = PVM(environment_test.episode_length, portfolio_size=len(br_tickers))
while not done:
    last_action = pvm.retrieve()
    obs_batch = np.expand_dims(obs, axis=0)
    last_action_batch = np.expand_dims(last_action, axis=0)
    action = policy(obs_batch, last_action_batch)
    pvm.add(action)
    obs, _, done, _ = environment_test.step(action)
# Out:
# =================================
# Initial portfolio value:100000
# Final portfolio value: 190535.640625
# Final accumulative portfolio value: 1.90535640625
# Maximum DrawDown: -0.2284991142051831
# Sharpe ratio: 1.6187426778441416
# =================================

# %% [markdown]
# ## Avaliação dos resultados
#
# Realização de uma análise da performance ao longo de 2016.

# %%
# Importação do módulo responsável por avaliar a performance doo modelo ao longo de seu teste
from quantamental_lib import Backtest

bk = Backtest(test_environment= environment_test, portfolio_vector = pvm)

# %%
# Criação de um DataFrame contendo os retornos da estratégia e dos principais benchmarks (CDI e IBOV)
df = bk.general_cumulative_daily_returns()

# Salva o DataFrame em um arquivo CSV
df.to_csv('results_df/results_2016.csv', index=True)

display(df)
# Out:
#             Cumulative Daily Returns      IBOV       CDI
# 2016-01-05                  1.000000  1.000000  1.000525
# 2016-01-06                  0.998000  0.984771  1.001051
# 2016-01-07                  0.958743  0.959358  1.001577
# 2016-01-08                  0.961818  0.957401  1.002103
# 2016-01-11                  0.940988  0.941795  1.002629
# ...                              ...       ...       ...
# 2016-12-22                  1.700470  1.349749  1.136121
# 2016-12-23                  1.696983  1.365827  1.136698
# 2016-12-27                  1.717726  1.383743  1.137853
# 2016-12-28                  1.768792  1.409321  1.138430
# 2016-12-29                  1.780648  1.419812  1.139009
#
# [241 rows x 3 columns]

# %%
# Avaliação do índice de Sharpe do modelo
sharpe_ratio = bk.sharpe_ratio(risk_free_rate=0)
print('Sharpe Ratio: ', sharpe_ratio)

# Avaliação da taxa de acerto do modelo
hit_ratio = bk.hit_ratio()
print('Hit ratio: ', hit_ratio)
# Out:
# Sharpe Ratio:  1.4767224730349247
# Hit ratio:  0.5850622406639004

# %%
# Plotagem dos resultados para facilitar sua comparação
import matplotlib.pyplot as plt

plt.figure(figsize=(12, 6)) 

plt.plot(df['Cumulative Daily Returns'], label='Estratégia', color ='blue')  
plt.plot(df['IBOV'], label='IBOV', color ='orange')  
plt.plot(df['CDI'], label='CDI', color ='green')  

plt.legend()

plt.ylabel('Retorno acumulado')
plt.xlabel('Data')

plt.show()
