# %% [markdown]
# ### Análise do ano de 2021
#
# Utilizando como base o trabalho descrito em "https://sol.sbc.org.br/index.php/bwaif/article/view/24959", este notebook desenvolverá um alocador de portfólio baseado em aprendizado por reforço, sendo sua performance avaliada ao longo do ano de 2021.

# %%
# Importação do diretório atual de trabalho
import sys
upper_path = sys.path[0][:-8]
sys.path.append(upper_path)

# Importação d0 módulo responsável por criar o banco de dados personalizado
from quantamental_lib import RLDatabase

# Importação de bibliotecas auxiliares
import pandas as pd
import torch

# %%
# Criação dos bancos de dados. Os dados de treino e teste são igualmente distribuídos com base na quantidade máxima de ativos selecionada (30).
rl_db = RLDatabase(end_train = '2020-12-31',end_test='2021-12-31', test_time_window=50)

# Leitura ou criação dos DataFrames de treino e teste
try:
    train_df = pd.read_csv('train_test_dfs/train_2021.csv')
except:
    train_df = rl_db.create_train_database()
    train_df.to_csv('train_test_dfs/train_2021.csv', index=False)

try:
    test_df = pd.read_csv('train_test_dfs/test_2021.csv')
except:
    test_df = rl_db.create_test_database()
    test_df.to_csv('train_test_dfs/test_2021.csv', index=False)

# Universo de tickers disponíveis
br_tickers = train_df.tic.unique()

print(br_tickers)
# Out:
# ['ABEV3' 'B3SA3' 'BBAS3' 'BBDC4' 'BHIA3' 'BRFS3' 'CIEL3' 'CMIG4' 'COGN3'
#  'CPLE6' 'CSAN3' 'CSNA3' 'EMBR3' 'FNOR11' 'GGBR4' 'GOAU4' 'GOLL4' 'ITSA4'
#  'ITUB4' 'JBSS3' 'MEAL3' 'MGLU3' 'OIBR3' 'PETR3' 'PETR4' 'PRIO3' 'USIM5'
#  'VALE3' 'WEGE3']

# %% [markdown]
# ### Treino do modelo
#
# O ambiente será treinado ao longo de 100 episódios, sendo sua taxa de aprendizado igual a 0.001.

# %%
# Importação do módulo contendo as principais classes necessárias para o treinamento
from quantamental_lib.finRL_POE import *

# Definição das features que serão avaliados pelo modelo
features = ['open', 'high', 'low', 'close', 'volume', 'rsi', 'mom', 'cci', 'stoch',
       'williams', 'macd', 'macd_signal', 'bband', 'USD/BRL', 'IBOV', 'SPX',
       'DJI', 'CDI', 'NASDAQ', 'IPCA', 'SELIC', 'IGPM', 'day']

# %%
# Ambiente de Treino
environment = PortfolioOptimizationEnv(
        train_df,
        initial_amount=100000,
        comission_fee_pct=0,
        time_window=50,
        features=features
    )

# Treinamento do modelo
algo = PG(environment, lr=0.001, portfolio_size = len(br_tickers))
algo.train(episodes=100)

# Salvando o modelo treinado
torch.save(algo.target_policy.state_dict(), "trained_models/policy_EIIE_2021.pt")
# Out:
#   0%|          | 0/100 [00:00<?, ?it/s]
# =================================
# Initial portfolio value:100000
# Final portfolio value: 539862.6875
# Final accumulative portfolio value: 5.398626875
# Maximum DrawDown: -0.5159457940781784
# Sharpe ratio: 0.9603199846343798
# =================================
# =================================
# Initial portfolio value:100000
# Final portfolio value: 564332.9375
# Final accumulative portfolio value: 5.643329375
# Maximum DrawDown: -0.5145197347787527
# Sharpe ratio: 0.9823372402447432
# =================================
# =================================
# Initial portfolio value:100000
# Final portfolio value: 585884.8125
# Final accumulative portfolio value: 5.858848125
# Maximum DrawDown: -0.5131420376496372
# Sharpe ratio: 1.0013994354158142
# =================================
# =================================
# Initial portfolio value:100000
# Final portfolio value: 618780.125
# Final accumulative portfolio value: 6.18780125
# Maximum DrawDown: -0.5112982622948907
# Sharpe ratio: 1.0282870800218238
# =================================
# =================================
# Initial portfolio value:100000
# Final portfolio value: 668036.75
# Final accumulative portfolio value: 6.6803675
# Maximum DrawDown: -0.5096232483196648
# Sharpe ratio: 1.065614766721456
# =================================
# =================================
# Initial portfolio value:100000
# Final portfolio value: 740267.0625
# Final accumulative portfolio value: 7.402670625
# Maximum DrawDown: -0.507471705612633
# Sharpe ratio: 1.1159792433734161
# =================================
# =================================
# Initial portfolio value:100000
# Final portfolio value: 853622.0
# Final accumulative portfolio value: 8.53622
# Maximum DrawDown: -0.5045849018281984
# Sharpe ratio: 1.1841290010684609
# =================================
# =================================
# Initial portfolio value:100000
# Final portfolio value: 1027650.875
# Final accumulative portfolio value: 10.27650875
# Maximum DrawDown: -0.5016881589174523
# Sharpe ratio: 1.2718131621499802
# =================================
# =================================
# Initial portfolio value:100000
# Final portfolio value: 1303280.0
# Final accumulative portfolio value: 13.0328
# Maximum DrawDown: -0.49970783692906606
# Sharpe ratio: 1.3784190842082817
# =================================
# =================================
# Initial portfolio value:100000
# Final portfolio value: 1761883.0
# Final accumulative portfolio value: 17.61883
# Maximum DrawDown: -0.49786058595172455
# Sharpe ratio: 1.5026878737154972
# =================================
# =================================
# Initial portfolio value:100000
# Final portfolio value: 2539978.75
# Final accumulative portfolio value: 25.3997875
# Maximum DrawDown: -0.4992404625197706
# Sharpe ratio: 1.6298233032097227
# =================================
# =================================
# Initial portfolio value:100000
# Final portfolio value: 3891717.0
# Final accumulative portfolio value: 38.91717
# Maximum DrawDown: -0.4970445251088884
# Sharpe ratio: 1.7476068393287378
# =================================
# =================================
# Initial portfolio value:100000
# Final portfolio value: 6249904.0
# Final accumulative portfolio value: 62.49904
# Maximum DrawDown: -0.498329345854012
# Sharpe ratio: 1.8388535987231813
# =================================
# =================================
# Initial portfolio value:100000
# Final portfolio value: 9986595.0
# Final accumulative portfolio value: 99.86595
# Maximum DrawDown: -0.49940528921511185
# Sharpe ratio: 1.898273659493102
# =================================
# =================================
# Initial portfolio value:100000
# Final portfolio value: 16688953.0
# Final accumulative portfolio value: 166.88953
# Maximum DrawDown: -0.4968822091509447
# Sharpe ratio: 1.9346360039997834
# =================================
# =================================
# Initial portfolio value:100000
# Final portfolio value: 26439538.0
# Final accumulative portfolio value: 264.39538
# Maximum DrawDown: -0.49582748928782483
# Sharpe ratio: 1.983250282983144
# =================================
# =================================
# Initial portfolio value:100000
# Final portfolio value: 43591216.0
# Final accumulative portfolio value: 435.91216
# Maximum DrawDown: -0.49332400012781874
# Sharpe ratio: 2.0250375992367884
# =================================
# =================================
# Initial portfolio value:100000
# Final portfolio value: 67040216.0
# Final accumulative portfolio value: 670.40216
# Maximum DrawDown: -0.49262969569957726
# Sharpe ratio: 2.0789816021172824
# =================================
# =================================
# Initial portfolio value:100000
# Final portfolio value: 105530456.0
# Final accumulative portfolio value: 1055.30456
# Maximum DrawDown: -0.4914386038083721
# Sharpe ratio: 2.132540012717079
# =================================
# =================================
# Initial portfolio value:100000
# Final portfolio value: 156202480.0
# Final accumulative portfolio value: 1562.0248
# Maximum DrawDown: -0.4878791730200146
# Sharpe ratio: 2.1873841716806073
# =================================
# =================================
# Initial portfolio value:100000
# Final portfolio value: 247984864.0
# Final accumulative portfolio value: 2479.84864
# Maximum DrawDown: -0.49347265695595766
# Sharpe ratio: 2.2373662575033615
# =================================
# =================================
# Initial portfolio value:100000
# Final portfolio value: 424598240.0
# Final accumulative portfolio value: 4245.9824
# Maximum DrawDown: -0.49585780623884645
# Sharpe ratio: 2.284343247869817
# =================================
# =================================
# Initial portfolio value:100000
# Final portfolio value: 675609920.0
# Final accumulative portfolio value: 6756.0992
# Maximum DrawDown: -0.4964481765433105
# Sharpe ratio: 2.2205694626573407
# =================================
# =================================
# Initial portfolio value:100000
# Final portfolio value: 1173535104.0
# Final accumulative portfolio value: 11735.35104
# Maximum DrawDown: -0.4985008934481423
# Sharpe ratio: 2.1506978709514226
# =================================
# =================================
# Initial portfolio value:100000
# Final portfolio value: 1871351424.0
# Final accumulative portfolio value: 18713.51424
# Maximum DrawDown: -0.49852418852691016
# Sharpe ratio: 2.121261823616453
# =================================
# =================================
# Initial portfolio value:100000
# Final portfolio value: 2805656576.0
# Final accumulative portfolio value: 28056.56576
# Maximum DrawDown: -0.49879700545201533
# Sharpe ratio: 2.1167547910482383
# =================================
# =================================
# Initial portfolio value:100000
# Final portfolio value: 3958517504.0
# Final accumulative portfolio value: 39585.17504
# Maximum DrawDown: -0.5002209085474842
# Sharpe ratio: 2.1231380384239764
# =================================
# =================================
# Initial portfolio value:100000
# Final portfolio value: 5553498112.0
# Final accumulative portfolio value: 55534.98112
# Maximum DrawDown: -0.49938118691524347
# Sharpe ratio: 2.1351640564696748
# =================================
# =================================
# Initial portfolio value:100000
# Final portfolio value: 7709697536.0
# Final accumulative portfolio value: 77096.97536
# Maximum DrawDown: -0.4983045109464609
# Sharpe ratio: 2.156624803004206
# =================================
# =================================
# Initial portfolio value:100000
# Final portfolio value: 10773792768.0
# Final accumulative portfolio value: 107737.92768
# Maximum DrawDown: -0.49763508830297487
# Sharpe ratio: 2.1805589361259448
# =================================
# =================================
# Initial portfolio value:100000
# Final portfolio value: 14688223232.0
# Final accumulative portfolio value: 146882.23232
# Maximum DrawDown: -0.49886600453747687
# Sharpe ratio: 2.2058741577998413
# =================================
# =================================
# Initial portfolio value:100000
# Final portfolio value: 19260545024.0
# Final accumulative portfolio value: 192605.45024
# Maximum DrawDown: -0.4983935757632457
# Sharpe ratio: 2.222780602070073
# =================================
# =================================
# Initial portfolio value:100000
# Final portfolio value: 24992315392.0
# Final accumulative portfolio value: 249923.15392
# Maximum DrawDown: -0.49642248361367225
# Sharpe ratio: 2.238799350258097
# =================================
# =================================
# Initial portfolio value:100000
# Final portfolio value: 31844833280.0
# Final accumulative portfolio value: 318448.3328
# Maximum DrawDown: -0.49598923628043945
# Sharpe ratio: 2.2578506982997313
# =================================
# =================================
# Initial portfolio value:100000
# Final portfolio value: 40127135744.0
# Final accumulative portfolio value: 401271.35744
# Maximum DrawDown: -0.49555510980398476
# Sharpe ratio: 2.2748578786181506
# =================================
# =================================
# Initial portfolio value:100000
# Final portfolio value: 49263857664.0
# Final accumulative portfolio value: 492638.57664
# Maximum DrawDown: -0.4954442550660044
# Sharpe ratio: 2.291644006452055
# =================================
# =================================
# Initial portfolio value:100000
# Final portfolio value: 60860325888.0
# Final accumulative portfolio value: 608603.25888
# Maximum DrawDown: -0.493884879484653
# Sharpe ratio: 2.3107706428177006
# =================================
# =================================
# Initial portfolio value:100000
# Final portfolio value: 73581715456.0
# Final accumulative portfolio value: 735817.15456
# Maximum DrawDown: -0.49508120801733413
# Sharpe ratio: 2.3303453635179814
# =================================
# =================================
# Initial portfolio value:100000
# Final portfolio value: 90287890432.0
# Final accumulative portfolio value: 902878.90432
# Maximum DrawDown: -0.4950241721997759
# Sharpe ratio: 2.3517272957689803
# =================================
# =================================
# Initial portfolio value:100000
# Final portfolio value: 106116087808.0
# Final accumulative portfolio value: 1061160.87808
# Maximum DrawDown: -0.4959040939134989
# Sharpe ratio: 2.368110938065333
# =================================
# =================================
# Initial portfolio value:100000
# Final portfolio value: 129296678912.0
# Final accumulative portfolio value: 1292966.78912
# Maximum DrawDown: -0.4962865653823182
# Sharpe ratio: 2.3892543053169253
# =================================
# =================================
# Initial portfolio value:100000
# Final portfolio value: 150885056512.0
# Final accumulative portfolio value: 1508850.56512
# Maximum DrawDown: -0.4977889003347866
# Sharpe ratio: 2.406913979029548
# =================================
# =================================
# Initial portfolio value:100000
# Final portfolio value: 181150367744.0
# Final accumulative portfolio value: 1811503.67744
# Maximum DrawDown: -0.4984013757281095
# Sharpe ratio: 2.429199761855449
# =================================
# =================================
# Initial portfolio value:100000
# Final portfolio value: 210267111424.0
# Final accumulative portfolio value: 2102671.11424
# Maximum DrawDown: -0.5010105987474465
# Sharpe ratio: 2.4465680005241315
# =================================
# =================================
# Initial portfolio value:100000
# Final portfolio value: 252889939968.0
# Final accumulative portfolio value: 2528899.39968
# Maximum DrawDown: -0.5011351536198558
# Sharpe ratio: 2.46779262544276
# =================================
# =================================
# Initial portfolio value:100000
# Final portfolio value: 286894096384.0
# Final accumulative portfolio value: 2868940.96384
# Maximum DrawDown: -0.5042134820821672
# Sharpe ratio: 2.4824605582586923
# =================================
# =================================
# Initial portfolio value:100000
# Final portfolio value: 347456634880.0
# Final accumulative portfolio value: 3474566.3488
# Maximum DrawDown: -0.504648811698502
# Sharpe ratio: 2.5068789162356606
# =================================
# =================================
# Initial portfolio value:100000
# Final portfolio value: 392601665536.0
# Final accumulative portfolio value: 3926016.65536
# Maximum DrawDown: -0.5071354917359765
# Sharpe ratio: 2.5211120034287107
# =================================
# =================================
# Initial portfolio value:100000
# Final portfolio value: 478818238464.0
# Final accumulative portfolio value: 4788182.38464
# Maximum DrawDown: -0.5073037174993122
# Sharpe ratio: 2.546640616677543
# =================================
# =================================
# Initial portfolio value:100000
# Final portfolio value: 548875042816.0
# Final accumulative portfolio value: 5488750.42816
# Maximum DrawDown: -0.5089027565777785
# Sharpe ratio: 2.56232927078306
# =================================
# =================================
# Initial portfolio value:100000
# Final portfolio value: 648402698240.0
# Final accumulative portfolio value: 6484026.9824
# Maximum DrawDown: -0.5100519068220704
# Sharpe ratio: 2.5857865809087803
# =================================
# =================================
# Initial portfolio value:100000
# Final portfolio value: 719176990720.0
# Final accumulative portfolio value: 7191769.9072
# Maximum DrawDown: -0.5131108425426675
# Sharpe ratio: 2.597813395902652
# =================================
# =================================
# Initial portfolio value:100000
# Final portfolio value: 871037599744.0
# Final accumulative portfolio value: 8710375.99744
# Maximum DrawDown: -0.5119928770686479
# Sharpe ratio: 2.6228802263259627
# =================================
# =================================
# Initial portfolio value:100000
# Final portfolio value: 989638557696.0
# Final accumulative portfolio value: 9896385.57696
# Maximum DrawDown: -0.510985578096803
# Sharpe ratio: 2.637192152472492
# =================================
# =================================
# Initial portfolio value:100000
# Final portfolio value: 1123317055488.0
# Final accumulative portfolio value: 11233170.55488
# Maximum DrawDown: -0.5133285643109402
# Sharpe ratio: 2.6550952135339143
# =================================
# =================================
# Initial portfolio value:100000
# Final portfolio value: 1332992671744.0
# Final accumulative portfolio value: 13329926.71744
# Maximum DrawDown: -0.5127673334327232
# Sharpe ratio: 2.677058168928616
# =================================
# =================================
# Initial portfolio value:100000
# Final portfolio value: 1449837985792.0
# Final accumulative portfolio value: 14498379.85792
# Maximum DrawDown: -0.515354974991098
# Sharpe ratio: 2.6856377728184704
# =================================
# =================================
# Initial portfolio value:100000
# Final portfolio value: 1701797167104.0
# Final accumulative portfolio value: 17017971.67104
# Maximum DrawDown: -0.5137654645112302
# Sharpe ratio: 2.7070534304680622
# =================================
# =================================
# Initial portfolio value:100000
# Final portfolio value: 1855506612224.0
# Final accumulative portfolio value: 18555066.12224
# Maximum DrawDown: -0.515578432884037
# Sharpe ratio: 2.7166880144633834
# =================================
# =================================
# Initial portfolio value:100000
# Final portfolio value: 2119460192256.0
# Final accumulative portfolio value: 21194601.92256
# Maximum DrawDown: -0.514673725787931
# Sharpe ratio: 2.7335696052102896
# =================================
# =================================
# Initial portfolio value:100000
# Final portfolio value: 2281304752128.0
# Final accumulative portfolio value: 22813047.52128
# Maximum DrawDown: -0.5167012013094587
# Sharpe ratio: 2.7424062235856264
# =================================
# =================================
# Initial portfolio value:100000
# Final portfolio value: 2583740022784.0
# Final accumulative portfolio value: 25837400.22784
# Maximum DrawDown: -0.5155210992336354
# Sharpe ratio: 2.757805534218684
# =================================
# =================================
# Initial portfolio value:100000
# Final portfolio value: 2784260259840.0
# Final accumulative portfolio value: 27842602.5984
# Maximum DrawDown: -0.5171611128883778
# Sharpe ratio: 2.76746827857269
# =================================
# =================================
# Initial portfolio value:100000
# Final portfolio value: 3094529179648.0
# Final accumulative portfolio value: 30945291.79648
# Maximum DrawDown: -0.5169051003855398
# Sharpe ratio: 2.780355174369132
# =================================
# =================================
# Initial portfolio value:100000
# Final portfolio value: 3381473312768.0
# Final accumulative portfolio value: 33814733.12768
# Maximum DrawDown: -0.5176956520161068
# Sharpe ratio: 2.7921457304503723
# =================================
# =================================
# Initial portfolio value:100000
# Final portfolio value: 3706297516032.0
# Final accumulative portfolio value: 37062975.16032
# Maximum DrawDown: -0.5174883283517833
# Sharpe ratio: 2.8040683075447665
# =================================
# =================================
# Initial portfolio value:100000
# Final portfolio value: 4059485962240.0
# Final accumulative portfolio value: 40594859.6224
# Maximum DrawDown: -0.5175868183582557
# Sharpe ratio: 2.815437498752523
# =================================
# =================================
# Initial portfolio value:100000
# Final portfolio value: 4401384652800.0
# Final accumulative portfolio value: 44013846.528
# Maximum DrawDown: -0.5173320193907351
# Sharpe ratio: 2.826882499602919
# =================================
# =================================
# Initial portfolio value:100000
# Final portfolio value: 4803035398144.0
# Final accumulative portfolio value: 48030353.98144
# Maximum DrawDown: -0.5175848194964643
# Sharpe ratio: 2.8377904417840316
# =================================
# =================================
# Initial portfolio value:100000
# Final portfolio value: 5287923154944.0
# Final accumulative portfolio value: 52879231.54944
# Maximum DrawDown: -0.5163968683372799
# Sharpe ratio: 2.8515412078730735
# =================================
# =================================
# Initial portfolio value:100000
# Final portfolio value: 5708631244800.0
# Final accumulative portfolio value: 57086312.448
# Maximum DrawDown: -0.5158638452764657
# Sharpe ratio: 2.861710595292585
# =================================
# =================================
# Initial portfolio value:100000
# Final portfolio value: 6264558452736.0
# Final accumulative portfolio value: 62645584.52736
# Maximum DrawDown: -0.5152312064964436
# Sharpe ratio: 2.874322730724886
# =================================
# =================================
# Initial portfolio value:100000
# Final portfolio value: 6832623976448.0
# Final accumulative portfolio value: 68326239.76448
# Maximum DrawDown: -0.5137817469586523
# Sharpe ratio: 2.8864325544806437
# =================================
# =================================
# Initial portfolio value:100000
# Final portfolio value: 7446872981504.0
# Final accumulative portfolio value: 74468729.81504
# Maximum DrawDown: -0.5122743285468303
# Sharpe ratio: 2.898472005277527
# =================================
# =================================
# Initial portfolio value:100000
# Final portfolio value: 8030706466816.0
# Final accumulative portfolio value: 80307064.66816
# Maximum DrawDown: -0.5112381135210398
# Sharpe ratio: 2.908422212409551
# =================================
# =================================
# Initial portfolio value:100000
# Final portfolio value: 8709141954560.0
# Final accumulative portfolio value: 87091419.5456
# Maximum DrawDown: -0.5100443017347676
# Sharpe ratio: 2.920180486441037
# =================================
# =================================
# Initial portfolio value:100000
# Final portfolio value: 9427917733888.0
# Final accumulative portfolio value: 94279177.33888
# Maximum DrawDown: -0.5088990822234465
# Sharpe ratio: 2.9307748575683212
# =================================
# =================================
# Initial portfolio value:100000
# Final portfolio value: 10211946397696.0
# Final accumulative portfolio value: 102119463.97696
# Maximum DrawDown: -0.5071589005645181
# Sharpe ratio: 2.9429343739350466
# =================================
# =================================
# Initial portfolio value:100000
# Final portfolio value: 10916489854976.0
# Final accumulative portfolio value: 109164898.54976
# Maximum DrawDown: -0.5063786227417943
# Sharpe ratio: 2.951736901316831
# =================================
# =================================
# Initial portfolio value:100000
# Final portfolio value: 11867557724160.0
# Final accumulative portfolio value: 118675577.2416
# Maximum DrawDown: -0.5050481588853354
# Sharpe ratio: 2.9629338554998785
# =================================
# =================================
# Initial portfolio value:100000
# Final portfolio value: 12800520880128.0
# Final accumulative portfolio value: 128005208.80128
# Maximum DrawDown: -0.5035322232692947
# Sharpe ratio: 2.9746254617992722
# =================================
# =================================
# Initial portfolio value:100000
# Final portfolio value: 13749108867072.0
# Final accumulative portfolio value: 137491088.67072
# Maximum DrawDown: -0.5023421579611316
# Sharpe ratio: 2.985600254483164
# =================================
# =================================
# Initial portfolio value:100000
# Final portfolio value: 14746494435328.0
# Final accumulative portfolio value: 147464944.35328
# Maximum DrawDown: -0.5012105603479948
# Sharpe ratio: 2.994974122854817
# =================================
# =================================
# Initial portfolio value:100000
# Final portfolio value: 15864521818112.0
# Final accumulative portfolio value: 158645218.18112
# Maximum DrawDown: -0.4995690249620742
# Sharpe ratio: 3.0059362388199466
# =================================
# =================================
# Initial portfolio value:100000
# Final portfolio value: 16908814385152.0
# Final accumulative portfolio value: 169088143.85152
# Maximum DrawDown: -0.49860603294976624
# Sharpe ratio: 3.015132610446295
# =================================
# =================================
# Initial portfolio value:100000
# Final portfolio value: 18258398806016.0
# Final accumulative portfolio value: 182583988.06016
# Maximum DrawDown: -0.49747299894721275
# Sharpe ratio: 3.025387879075152
# =================================
# =================================
# Initial portfolio value:100000
# Final portfolio value: 19496871919616.0
# Final accumulative portfolio value: 194968719.19616
# Maximum DrawDown: -0.49594936608742535
# Sharpe ratio: 3.0351515790417576
# =================================
# =================================
# Initial portfolio value:100000
# Final portfolio value: 21015176413184.0
# Final accumulative portfolio value: 210151764.13184
# Maximum DrawDown: -0.4945133777223044
# Sharpe ratio: 3.04611233904097
# =================================
# =================================
# Initial portfolio value:100000
# Final portfolio value: 22095763341312.0
# Final accumulative portfolio value: 220957633.41312
# Maximum DrawDown: -0.4931255272268624
# Sharpe ratio: 3.052664212460439
# =================================
# =================================
# Initial portfolio value:100000
# Final portfolio value: 23795727335424.0
# Final accumulative portfolio value: 237957273.35424
# Maximum DrawDown: -0.49224588037034933
# Sharpe ratio: 3.062435782175956
# =================================
# =================================
# Initial portfolio value:100000
# Final portfolio value: 25068428066816.0
# Final accumulative portfolio value: 250684280.66816
# Maximum DrawDown: -0.49085437509431795
# Sharpe ratio: 3.068725577850343
# =================================
# =================================
# Initial portfolio value:100000
# Final portfolio value: 26822154649600.0
# Final accumulative portfolio value: 268221546.496
# Maximum DrawDown: -0.49080541960127355
# Sharpe ratio: 3.077000406577112
# =================================
# =================================
# Initial portfolio value:100000
# Final portfolio value: 28478378344448.0
# Final accumulative portfolio value: 284783783.44448
# Maximum DrawDown: -0.48913619287566723
# Sharpe ratio: 3.0849042525217314
# =================================
# =================================
# Initial portfolio value:100000
# Final portfolio value: 31041261666304.0
# Final accumulative portfolio value: 310412616.66304
# Maximum DrawDown: -0.48816613977238765
# Sharpe ratio: 3.096428493670672
# =================================
# =================================
# Initial portfolio value:100000
# Final portfolio value: 32847987474432.0
# Final accumulative portfolio value: 328479874.74432
# Maximum DrawDown: -0.48695233769752977
# Sharpe ratio: 3.104300908947194
# =================================
# =================================
# Initial portfolio value:100000
# Final portfolio value: 35441583587328.0
# Final accumulative portfolio value: 354415835.87328
# Maximum DrawDown: -0.48550185858364714
# Sharpe ratio: 3.114517464598953
# =================================
# =================================
# Initial portfolio value:100000
# Final portfolio value: 37273416499200.0
# Final accumulative portfolio value: 372734164.992
# Maximum DrawDown: -0.4841209673184377
# Sharpe ratio: 3.1210945318725343
# =================================
# =================================
# Initial portfolio value:100000
# Final portfolio value: 39813994512384.0
# Final accumulative portfolio value: 398139945.12384
# Maximum DrawDown: -0.483040837589896
# Sharpe ratio: 3.1297349279088107
# =================================
# =================================
# Initial portfolio value:100000
# Final portfolio value: 42620378152960.0
# Final accumulative portfolio value: 426203781.5296
# Maximum DrawDown: -0.4816312503276098
# Sharpe ratio: 3.1395332859384926
# =================================
# =================================
# Initial portfolio value:100000
# Final portfolio value: 45099085987840.0
# Final accumulative portfolio value: 450990859.8784
# Maximum DrawDown: -0.4808038313660208
# Sharpe ratio: 3.1463846522429293
# =================================

# %% [markdown]
# ## Teste do modelo
#
# Após o treinamento, será criado um novo ambiente de teste utilizado para a avaliação de sua performance no ano de 2021.

# %%
# Ambiente de teste
environment_test = PortfolioOptimizationEnv(
        test_df,
        initial_amount=100000,
        comission_fee_pct=0,
        time_window=50,
        features=features
    )

# Importação e preparação do modelo treinado
policy = GradientPolicy()
policy.load_state_dict(torch.load("trained_models/policy_EIIE_2021.pt"))
policy = policy.to(device)

# Obtenção das métricas ao longo de 2021
done = False
obs = environment_test.reset()
pvm = PVM(environment_test.episode_length, portfolio_size=len(br_tickers))
while not done:
    last_action = pvm.retrieve()
    obs_batch = np.expand_dims(obs, axis=0)
    last_action_batch = np.expand_dims(last_action, axis=0)
    action = policy(obs_batch, last_action_batch)
    pvm.add(action)
    obs, _, done, _ = environment_test.step(action)

# %% [markdown]
# ## Avaliação dos resultados
#
# Realização de uma análise da performance ao longo de 2021.

# %%
# Importação do módulo responsável por avaliar a performance doo modelo ao longo de seu teste
from quantamental_lib import Backtest

bk = Backtest(test_environment= environment_test, portfolio_vector = pvm)

# %%
# Criação de um DataFrame contendo os retornos da estratégia e dos principais benchmarks (CDI e IBOV)
df = bk.general_cumulative_daily_returns()

# Salva o DataFrame em um arquivo CSV
df.to_csv('results_df/results_2021.csv', index=True)

display(df)
# Out:
#             Cumulative Daily Returns      IBOV       CDI
# 2021-01-04                  1.000000  1.000000  1.000075
# 2021-01-05                  0.989894  1.005609  1.000149
# 2021-01-06                  1.027700  1.010906  1.000224
# 2021-01-07                  1.071248  1.028661  1.000299
# 2021-01-08                  1.077340  1.054986  1.000374
# ...                              ...       ...       ...
# 2021-12-23                  0.877678  0.884723  1.042062
# 2021-12-27                  0.891707  0.890121  1.042786
# 2021-12-28                  0.865392  0.884495  1.043148
# 2021-12-29                  0.857247  0.878110  1.043511
# 2021-12-30                  0.866445  0.884141  1.043873
#
# [242 rows x 3 columns]

# %%
# Avaliação do índice de Sharpe do modelo
sharpe_ratio = bk.sharpe_ratio(risk_free_rate=0)
print('Sharpe Ratio: ', sharpe_ratio)

# Avaliação da taxa de acerto do modelo
hit_ratio = bk.hit_ratio()
print('Hit ratio: ', hit_ratio)
# Out:
# Sharpe Ratio:  -0.23462539787685205
# Hit ratio:  0.5041322314049587

# %%
# Plotagem dos resultados para facilitar sua comparação
import matplotlib.pyplot as plt

plt.figure(figsize=(12, 6)) 

plt.plot(df['Cumulative Daily Returns'], label='Estratégia', color ='blue')  
plt.plot(df['IBOV'], label='IBOV', color ='orange')  
plt.plot(df['CDI'], label='CDI', color ='green')  

plt.legend()

plt.ylabel('Retorno acumulado')
plt.xlabel('Data')

plt.show()
