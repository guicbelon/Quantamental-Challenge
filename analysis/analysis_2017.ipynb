# %% [markdown]
# ### Análise do ano de 2017
#
# Utilizando como base o trabalho descrito em "https://sol.sbc.org.br/index.php/bwaif/article/view/24959", este notebook desenvolverá um alocador de portfólio baseado em aprendizado por reforço, sendo sua performance avaliada ao longo do ano de 2017.

# %%
# Importação do diretório atual de trabalho
import sys
upper_path = sys.path[0][:-8]
sys.path.append(upper_path)

# Importação d0 módulo responsável por criar o banco de dados personalizado
from quantamental_lib import RLDatabase

# Importação de bibliotecas auxiliares
import pandas as pd
import torch

# %%
# Criação dos bancos de dados. Os dados de treino e teste são igualmente distribuídos com base na quantidade máxima de ativos selecionada (30).
rl_db = RLDatabase(end_train = '2016-12-31',end_test='2017-12-31', test_time_window=50)

# Leitura ou criação dos DataFrames de treino e teste
try:
    train_df = pd.read_csv('train_test_dfs/train_2017.csv')
except:
    train_df = rl_db.create_train_database()
    train_df.to_csv('train_test_dfs/train_2017.csv', index=False)

try:
    test_df = pd.read_csv('train_test_dfs/test_2017.csv')
except:
    test_df = rl_db.create_test_database()
    test_df.to_csv('train_test_dfs/test_2017.csv', index=False)

# Universo de tickers disponíveis
br_tickers = train_df.tic.unique()

print(br_tickers)
# Out:
# ['ABEV3' 'B3SA3' 'BBAS3' 'BBDC3' 'BBDC4' 'BOVA11' 'BRAP4' 'CCRO3' 'CIEL3'
#  'CMIG4' 'CPLE6' 'CSAN3' 'CSNA3' 'EMBR3' 'EQTL3' 'FNOR11' 'GGBR4' 'GOAU4'
#  'ITSA4' 'ITUB4' 'JBSS3' 'LREN3' 'PETR3' 'PETR4' 'RADL3' 'RENT3' 'SAPR4'
#  'USIM5' 'VALE3' 'WEGE3']

# %% [markdown]
# ### Treino do modelo
#
# O ambiente será treinado ao longo de 100 episódios, sendo sua taxa de aprendizado igual a 0.001.

# %%
# Importação do módulo contendo as principais classes necessárias para o treinamento
from quantamental_lib.finRL_POE import *

# Definição das features que serão avaliados pelo modelo
features = ['open', 'high', 'low', 'close', 'volume', 'rsi', 'mom', 'cci', 'stoch',
       'williams', 'macd', 'macd_signal', 'bband', 'USD/BRL', 'IBOV', 'SPX',
       'DJI', 'CDI', 'NASDAQ', 'IPCA', 'SELIC', 'IGPM', 'day']

# %%
# Ambiente de Treino
environment = PortfolioOptimizationEnv(
        train_df,
        initial_amount=100000,
        comission_fee_pct=0,
        time_window=50,
        features=features
    )

# Treinamento do modelo
algo = PG(environment, lr=0.001, portfolio_size = len(br_tickers))
algo.train(episodes=100)

# Salvando o modelo treinado
torch.save(algo.target_policy.state_dict(), "trained_models/policy_EIIE_2017.pt")
# Out:
#   0%|          | 0/100 [00:00<?, ?it/s]
# =================================
# Initial portfolio value:100000
# Final portfolio value: 231464.375
# Final accumulative portfolio value: 2.31464375
# Maximum DrawDown: -0.412200067601582
# Sharpe ratio: 0.7976903352970325
# =================================
# =================================
# Initial portfolio value:100000
# Final portfolio value: 236131.109375
# Final accumulative portfolio value: 2.36131109375
# Maximum DrawDown: -0.4102318995635532
# Sharpe ratio: 0.8155945560717542
# =================================
# =================================
# Initial portfolio value:100000
# Final portfolio value: 239045.375
# Final accumulative portfolio value: 2.39045375
# Maximum DrawDown: -0.40773757351772943
# Sharpe ratio: 0.8277093849212283
# =================================
# =================================
# Initial portfolio value:100000
# Final portfolio value: 243263.15625
# Final accumulative portfolio value: 2.4326315625
# Maximum DrawDown: -0.4041389252917723
# Sharpe ratio: 0.8454439010000946
# =================================
# =================================
# Initial portfolio value:100000
# Final portfolio value: 249000.859375
# Final accumulative portfolio value: 2.49000859375
# Maximum DrawDown: -0.39972971174093463
# Sharpe ratio: 0.8688229159124133
# =================================
# =================================
# Initial portfolio value:100000
# Final portfolio value: 256727.578125
# Final accumulative portfolio value: 2.56727578125
# Maximum DrawDown: -0.3914686761682846
# Sharpe ratio: 0.9025883394138698
# =================================
# =================================
# Initial portfolio value:100000
# Final portfolio value: 267533.1875
# Final accumulative portfolio value: 2.675331875
# Maximum DrawDown: -0.37901755744267984
# Sharpe ratio: 0.9486314659923575
# =================================
# =================================
# Initial portfolio value:100000
# Final portfolio value: 281673.625
# Final accumulative portfolio value: 2.81673625
# Maximum DrawDown: -0.3571356741785837
# Sharpe ratio: 1.0112117914875731
# =================================
# =================================
# Initial portfolio value:100000
# Final portfolio value: 301732.25
# Final accumulative portfolio value: 3.0173225
# Maximum DrawDown: -0.3283454308946129
# Sharpe ratio: 1.0834962831205617
# =================================
# =================================
# Initial portfolio value:100000
# Final portfolio value: 325764.75
# Final accumulative portfolio value: 3.2576475
# Maximum DrawDown: -0.30424160713628756
# Sharpe ratio: 1.136291710199383
# =================================
# =================================
# Initial portfolio value:100000
# Final portfolio value: 351187.25
# Final accumulative portfolio value: 3.5118725
# Maximum DrawDown: -0.29912237534348984
# Sharpe ratio: 1.1503734483897008
# =================================
# =================================
# Initial portfolio value:100000
# Final portfolio value: 369730.9375
# Final accumulative portfolio value: 3.697309375
# Maximum DrawDown: -0.3049041511137599
# Sharpe ratio: 1.1365851311839037
# =================================
# =================================
# Initial portfolio value:100000
# Final portfolio value: 383167.875
# Final accumulative portfolio value: 3.83167875
# Maximum DrawDown: -0.3104613814564282
# Sharpe ratio: 1.1199533275443263
# =================================
# =================================
# Initial portfolio value:100000
# Final portfolio value: 390644.96875
# Final accumulative portfolio value: 3.9064496875
# Maximum DrawDown: -0.31382744427333353
# Sharpe ratio: 1.1079056336703188
# =================================
# =================================
# Initial portfolio value:100000
# Final portfolio value: 395665.4375
# Final accumulative portfolio value: 3.956654375
# Maximum DrawDown: -0.3159973015815484
# Sharpe ratio: 1.1000757453935364
# =================================
# =================================
# Initial portfolio value:100000
# Final portfolio value: 399384.4375
# Final accumulative portfolio value: 3.993844375
# Maximum DrawDown: -0.31712502722616875
# Sharpe ratio: 1.0968604813682696
# =================================
# =================================
# Initial portfolio value:100000
# Final portfolio value: 402596.6875
# Final accumulative portfolio value: 4.025966875
# Maximum DrawDown: -0.3175120450426392
# Sharpe ratio: 1.0977027210922687
# =================================
# =================================
# Initial portfolio value:100000
# Final portfolio value: 405640.375
# Final accumulative portfolio value: 4.05640375
# Maximum DrawDown: -0.31725323687669815
# Sharpe ratio: 1.102386991973203
# =================================
# =================================
# Initial portfolio value:100000
# Final portfolio value: 409201.5
# Final accumulative portfolio value: 4.092015
# Maximum DrawDown: -0.31645711800815657
# Sharpe ratio: 1.1108170532580037
# =================================
# =================================
# Initial portfolio value:100000
# Final portfolio value: 413889.25
# Final accumulative portfolio value: 4.1388925
# Maximum DrawDown: -0.3146175076490749
# Sharpe ratio: 1.1258974652393203
# =================================
# =================================
# Initial portfolio value:100000
# Final portfolio value: 420451.3125
# Final accumulative portfolio value: 4.204513125
# Maximum DrawDown: -0.3110930766853499
# Sharpe ratio: 1.1526170234285085
# =================================
# =================================
# Initial portfolio value:100000
# Final portfolio value: 431166.1875
# Final accumulative portfolio value: 4.311661875
# Maximum DrawDown: -0.3047862019408766
# Sharpe ratio: 1.1989138890865845
# =================================
# =================================
# Initial portfolio value:100000
# Final portfolio value: 450891.75
# Final accumulative portfolio value: 4.5089175
# Maximum DrawDown: -0.293211998196638
# Sharpe ratio: 1.2787205578130887
# =================================
# =================================
# Initial portfolio value:100000
# Final portfolio value: 492568.0
# Final accumulative portfolio value: 4.92568
# Maximum DrawDown: -0.2924538729588749
# Sharpe ratio: 1.3990764926317902
# =================================
# =================================
# Initial portfolio value:100000
# Final portfolio value: 580667.25
# Final accumulative portfolio value: 5.8066725
# Maximum DrawDown: -0.32199401679300044
# Sharpe ratio: 1.5232417330127765
# =================================
# =================================
# Initial portfolio value:100000
# Final portfolio value: 748938.875
# Final accumulative portfolio value: 7.48938875
# Maximum DrawDown: -0.3572301417897066
# Sharpe ratio: 1.5827765253159918
# =================================
# =================================
# Initial portfolio value:100000
# Final portfolio value: 1035899.4375
# Final accumulative portfolio value: 10.358994375
# Maximum DrawDown: -0.3783687899483892
# Sharpe ratio: 1.5660376807156033
# =================================
# =================================
# Initial portfolio value:100000
# Final portfolio value: 1543202.375
# Final accumulative portfolio value: 15.43202375
# Maximum DrawDown: -0.3770879882342959
# Sharpe ratio: 1.5398501551843773
# =================================
# =================================
# Initial portfolio value:100000
# Final portfolio value: 2324600.5
# Final accumulative portfolio value: 23.246005
# Maximum DrawDown: -0.35876073251089224
# Sharpe ratio: 1.5559370273714892
# =================================
# =================================
# Initial portfolio value:100000
# Final portfolio value: 3563818.75
# Final accumulative portfolio value: 35.6381875
# Maximum DrawDown: -0.32847808741035023
# Sharpe ratio: 1.6246457093226765
# =================================
# =================================
# Initial portfolio value:100000
# Final portfolio value: 5546181.0
# Final accumulative portfolio value: 55.46181
# Maximum DrawDown: -0.3084446514585981
# Sharpe ratio: 1.7194130722023686
# =================================
# =================================
# Initial portfolio value:100000
# Final portfolio value: 8416427.0
# Final accumulative portfolio value: 84.16427
# Maximum DrawDown: -0.2969095115256447
# Sharpe ratio: 1.8064917422962115
# =================================
# =================================
# Initial portfolio value:100000
# Final portfolio value: 12158315.0
# Final accumulative portfolio value: 121.58315
# Maximum DrawDown: -0.2830176753422664
# Sharpe ratio: 1.8863794316821971
# =================================
# =================================
# Initial portfolio value:100000
# Final portfolio value: 17427486.0
# Final accumulative portfolio value: 174.27486
# Maximum DrawDown: -0.2702505713286373
# Sharpe ratio: 1.9659496262650038
# =================================
# =================================
# Initial portfolio value:100000
# Final portfolio value: 24589106.0
# Final accumulative portfolio value: 245.89106
# Maximum DrawDown: -0.2540732078172361
# Sharpe ratio: 2.04714866206078
# =================================
# =================================
# Initial portfolio value:100000
# Final portfolio value: 33992968.0
# Final accumulative portfolio value: 339.92968
# Maximum DrawDown: -0.24490017908620543
# Sharpe ratio: 2.123951769190653
# =================================
# =================================
# Initial portfolio value:100000
# Final portfolio value: 46130636.0
# Final accumulative portfolio value: 461.30636
# Maximum DrawDown: -0.23765040736691267
# Sharpe ratio: 2.1995912451972126
# =================================
# =================================
# Initial portfolio value:100000
# Final portfolio value: 61897920.0
# Final accumulative portfolio value: 618.9792
# Maximum DrawDown: -0.23627043828380367
# Sharpe ratio: 2.2711982210578125
# =================================
# =================================
# Initial portfolio value:100000
# Final portfolio value: 81334008.0
# Final accumulative portfolio value: 813.34008
# Maximum DrawDown: -0.23822687425912825
# Sharpe ratio: 2.339928920150741
# =================================
# =================================
# Initial portfolio value:100000
# Final portfolio value: 109140016.0
# Final accumulative portfolio value: 1091.40016
# Maximum DrawDown: -0.23876454203757191
# Sharpe ratio: 2.4134762439356883
# =================================
# =================================
# Initial portfolio value:100000
# Final portfolio value: 143286000.0
# Final accumulative portfolio value: 1432.86
# Maximum DrawDown: -0.24103383011024826
# Sharpe ratio: 2.481052117146092
# =================================
# =================================
# Initial portfolio value:100000
# Final portfolio value: 187396736.0
# Final accumulative portfolio value: 1873.96736
# Maximum DrawDown: -0.2446201447145343
# Sharpe ratio: 2.542875386333079
# =================================
# =================================
# Initial portfolio value:100000
# Final portfolio value: 234110544.0
# Final accumulative portfolio value: 2341.10544
# Maximum DrawDown: -0.24812910830208768
# Sharpe ratio: 2.588933293158106
# =================================
# =================================
# Initial portfolio value:100000
# Final portfolio value: 279183936.0
# Final accumulative portfolio value: 2791.83936
# Maximum DrawDown: -0.2508524094458553
# Sharpe ratio: 2.624536099543376
# =================================
# =================================
# Initial portfolio value:100000
# Final portfolio value: 333705568.0
# Final accumulative portfolio value: 3337.05568
# Maximum DrawDown: -0.25294380749075673
# Sharpe ratio: 2.6586063158338704
# =================================
# =================================
# Initial portfolio value:100000
# Final portfolio value: 395369344.0
# Final accumulative portfolio value: 3953.69344
# Maximum DrawDown: -0.2540232557393496
# Sharpe ratio: 2.6897716752494425
# =================================
# =================================
# Initial portfolio value:100000
# Final portfolio value: 462896736.0
# Final accumulative portfolio value: 4628.96736
# Maximum DrawDown: -0.25458705116838
# Sharpe ratio: 2.7148811539599835
# =================================
# =================================
# Initial portfolio value:100000
# Final portfolio value: 547453760.0
# Final accumulative portfolio value: 5474.5376
# Maximum DrawDown: -0.2546867404816634
# Sharpe ratio: 2.733918504992349
# =================================
# =================================
# Initial portfolio value:100000
# Final portfolio value: 659357760.0
# Final accumulative portfolio value: 6593.5776
# Maximum DrawDown: -0.2545243994641121
# Sharpe ratio: 2.7404021615177445
# =================================
# =================================
# Initial portfolio value:100000
# Final portfolio value: 816718336.0
# Final accumulative portfolio value: 8167.18336
# Maximum DrawDown: -0.25461478918859526
# Sharpe ratio: 2.7296839979292096
# =================================
# =================================
# Initial portfolio value:100000
# Final portfolio value: 947822592.0
# Final accumulative portfolio value: 9478.22592
# Maximum DrawDown: -0.25377260166691695
# Sharpe ratio: 2.734435350259386
# =================================
# =================================
# Initial portfolio value:100000
# Final portfolio value: 1081875712.0
# Final accumulative portfolio value: 10818.75712
# Maximum DrawDown: -0.2539065462956758
# Sharpe ratio: 2.686530658848059
# =================================
# =================================
# Initial portfolio value:100000
# Final portfolio value: 1249147392.0
# Final accumulative portfolio value: 12491.47392
# Maximum DrawDown: -0.25376275402445236
# Sharpe ratio: 2.690136040084769
# =================================
# =================================
# Initial portfolio value:100000
# Final portfolio value: 1462507648.0
# Final accumulative portfolio value: 14625.07648
# Maximum DrawDown: -0.25385287783425214
# Sharpe ratio: 2.699189783465543
# =================================
# =================================
# Initial portfolio value:100000
# Final portfolio value: 1666892032.0
# Final accumulative portfolio value: 16668.92032
# Maximum DrawDown: -0.2527541880260217
# Sharpe ratio: 2.711368371603623
# =================================
# =================================
# Initial portfolio value:100000
# Final portfolio value: 1937075072.0
# Final accumulative portfolio value: 19370.75072
# Maximum DrawDown: -0.25346439153928857
# Sharpe ratio: 2.7327875939062056
# =================================
# =================================
# Initial portfolio value:100000
# Final portfolio value: 2256563712.0
# Final accumulative portfolio value: 22565.63712
# Maximum DrawDown: -0.2523929302187813
# Sharpe ratio: 2.751080203333345
# =================================
# =================================
# Initial portfolio value:100000
# Final portfolio value: 2697007360.0
# Final accumulative portfolio value: 26970.0736
# Maximum DrawDown: -0.25270011084398625
# Sharpe ratio: 2.778737617208127
# =================================
# =================================
# Initial portfolio value:100000
# Final portfolio value: 3077963264.0
# Final accumulative portfolio value: 30779.63264
# Maximum DrawDown: -0.2520281725872944
# Sharpe ratio: 2.7959117792485735
# =================================
# =================================
# Initial portfolio value:100000
# Final portfolio value: 3330706944.0
# Final accumulative portfolio value: 33307.06944
# Maximum DrawDown: -0.250644215628713
# Sharpe ratio: 2.834922941131202
# =================================
# =================================
# Initial portfolio value:100000
# Final portfolio value: 3850191104.0
# Final accumulative portfolio value: 38501.91104
# Maximum DrawDown: -0.2502414257553337
# Sharpe ratio: 2.8382057499151867
# =================================
# =================================
# Initial portfolio value:100000
# Final portfolio value: 4280225024.0
# Final accumulative portfolio value: 42802.25024
# Maximum DrawDown: -0.2491448049347813
# Sharpe ratio: 2.858602618208625
# =================================
# =================================
# Initial portfolio value:100000
# Final portfolio value: 4777255424.0
# Final accumulative portfolio value: 47772.55424
# Maximum DrawDown: -0.24766422883410422
# Sharpe ratio: 2.876681437063628
# =================================
# =================================
# Initial portfolio value:100000
# Final portfolio value: 5290587648.0
# Final accumulative portfolio value: 52905.87648
# Maximum DrawDown: -0.24609977511659997
# Sharpe ratio: 2.8936513634306364
# =================================
# =================================
# Initial portfolio value:100000
# Final portfolio value: 5768679424.0
# Final accumulative portfolio value: 57686.79424
# Maximum DrawDown: -0.24407963071646044
# Sharpe ratio: 2.9096224909988795
# =================================
# =================================
# Initial portfolio value:100000
# Final portfolio value: 6298613760.0
# Final accumulative portfolio value: 62986.1376
# Maximum DrawDown: -0.2417039195304006
# Sharpe ratio: 2.9267509802911382
# =================================
# =================================
# Initial portfolio value:100000
# Final portfolio value: 6904007168.0
# Final accumulative portfolio value: 69040.07168
# Maximum DrawDown: -0.23879770289033353
# Sharpe ratio: 2.943032541300132
# =================================
# =================================
# Initial portfolio value:100000
# Final portfolio value: 7662226432.0
# Final accumulative portfolio value: 76622.26432
# Maximum DrawDown: -0.23655615290287646
# Sharpe ratio: 2.960234519733088
# =================================
# =================================
# Initial portfolio value:100000
# Final portfolio value: 8331962368.0
# Final accumulative portfolio value: 83319.62368
# Maximum DrawDown: -0.23451771426734047
# Sharpe ratio: 2.9761249144347675
# =================================
# =================================
# Initial portfolio value:100000
# Final portfolio value: 8999255040.0
# Final accumulative portfolio value: 89992.5504
# Maximum DrawDown: -0.23230850965080152
# Sharpe ratio: 2.993368370895831
# =================================
# =================================
# Initial portfolio value:100000
# Final portfolio value: 9708183552.0
# Final accumulative portfolio value: 97081.83552
# Maximum DrawDown: -0.2304315853145943
# Sharpe ratio: 3.009658789760116
# =================================
# =================================
# Initial portfolio value:100000
# Final portfolio value: 10503469056.0
# Final accumulative portfolio value: 105034.69056
# Maximum DrawDown: -0.22761553888504882
# Sharpe ratio: 3.0254456908722895
# =================================
# =================================
# Initial portfolio value:100000
# Final portfolio value: 11445770240.0
# Final accumulative portfolio value: 114457.7024
# Maximum DrawDown: -0.22644884036997792
# Sharpe ratio: 3.0412641092526393
# =================================
# =================================
# Initial portfolio value:100000
# Final portfolio value: 12374072320.0
# Final accumulative portfolio value: 123740.7232
# Maximum DrawDown: -0.22429644106980184
# Sharpe ratio: 3.0574064827640224
# =================================
# =================================
# Initial portfolio value:100000
# Final portfolio value: 13304090624.0
# Final accumulative portfolio value: 133040.90624
# Maximum DrawDown: -0.2229375442327366
# Sharpe ratio: 3.0733854907638274
# =================================
# =================================
# Initial portfolio value:100000
# Final portfolio value: 14310047744.0
# Final accumulative portfolio value: 143100.47744
# Maximum DrawDown: -0.22220948187480238
# Sharpe ratio: 3.0878063829094144
# =================================
# =================================
# Initial portfolio value:100000
# Final portfolio value: 15284765696.0
# Final accumulative portfolio value: 152847.65696
# Maximum DrawDown: -0.2202571827565306
# Sharpe ratio: 3.102258134725435
# =================================
# =================================
# Initial portfolio value:100000
# Final portfolio value: 16369500160.0
# Final accumulative portfolio value: 163695.0016
# Maximum DrawDown: -0.21889902578949127
# Sharpe ratio: 3.116079356140262
# =================================
# =================================
# Initial portfolio value:100000
# Final portfolio value: 17617217536.0
# Final accumulative portfolio value: 176172.17536
# Maximum DrawDown: -0.21786296731369115
# Sharpe ratio: 3.128939750584442
# =================================
# =================================
# Initial portfolio value:100000
# Final portfolio value: 18711334912.0
# Final accumulative portfolio value: 187113.34912
# Maximum DrawDown: -0.2178470001488375
# Sharpe ratio: 3.1415012167676473
# =================================
# =================================
# Initial portfolio value:100000
# Final portfolio value: 19638288384.0
# Final accumulative portfolio value: 196382.88384
# Maximum DrawDown: -0.21502077335120384
# Sharpe ratio: 3.154355316383203
# =================================
# =================================
# Initial portfolio value:100000
# Final portfolio value: 20613154816.0
# Final accumulative portfolio value: 206131.54816
# Maximum DrawDown: -0.21477108864338978
# Sharpe ratio: 3.164717785975524
# =================================
# =================================
# Initial portfolio value:100000
# Final portfolio value: 21942845440.0
# Final accumulative portfolio value: 219428.4544
# Maximum DrawDown: -0.21135595556782627
# Sharpe ratio: 3.1756805661918768
# =================================
# =================================
# Initial portfolio value:100000
# Final portfolio value: 23409031168.0
# Final accumulative portfolio value: 234090.31168
# Maximum DrawDown: -0.21135688260504526
# Sharpe ratio: 3.184729397128131
# =================================
# =================================
# Initial portfolio value:100000
# Final portfolio value: 24813570048.0
# Final accumulative portfolio value: 248135.70048
# Maximum DrawDown: -0.2092848008438758
# Sharpe ratio: 3.1953173414997758
# =================================
# =================================
# Initial portfolio value:100000
# Final portfolio value: 25766389760.0
# Final accumulative portfolio value: 257663.8976
# Maximum DrawDown: -0.20802334874411577
# Sharpe ratio: 3.2049668542725973
# =================================
# =================================
# Initial portfolio value:100000
# Final portfolio value: 26876411904.0
# Final accumulative portfolio value: 268764.11904
# Maximum DrawDown: -0.2073547041977899
# Sharpe ratio: 3.214342846091277
# =================================
# =================================
# Initial portfolio value:100000
# Final portfolio value: 28258078720.0
# Final accumulative portfolio value: 282580.7872
# Maximum DrawDown: -0.2053643778156743
# Sharpe ratio: 3.2220123441122586
# =================================
# =================================
# Initial portfolio value:100000
# Final portfolio value: 29833676800.0
# Final accumulative portfolio value: 298336.768
# Maximum DrawDown: -0.20569392480208804
# Sharpe ratio: 3.229845091760147
# =================================
# =================================
# Initial portfolio value:100000
# Final portfolio value: 31631556608.0
# Final accumulative portfolio value: 316315.56608
# Maximum DrawDown: -0.2030053308655192
# Sharpe ratio: 3.2389987167312344
# =================================
# =================================
# Initial portfolio value:100000
# Final portfolio value: 33157621760.0
# Final accumulative portfolio value: 331576.2176
# Maximum DrawDown: -0.20466353228861256
# Sharpe ratio: 3.247282014568874
# =================================
# =================================
# Initial portfolio value:100000
# Final portfolio value: 34772062208.0
# Final accumulative portfolio value: 347720.62208
# Maximum DrawDown: -0.20220900619970394
# Sharpe ratio: 3.257100188870887
# =================================
# =================================
# Initial portfolio value:100000
# Final portfolio value: 36100861952.0
# Final accumulative portfolio value: 361008.61952
# Maximum DrawDown: -0.20466793803023164
# Sharpe ratio: 3.2648469177195403
# =================================
# =================================
# Initial portfolio value:100000
# Final portfolio value: 37808513024.0
# Final accumulative portfolio value: 378085.13024
# Maximum DrawDown: -0.2019052102186799
# Sharpe ratio: 3.2735377805828687
# =================================
# =================================
# Initial portfolio value:100000
# Final portfolio value: 39464566784.0
# Final accumulative portfolio value: 394645.66784
# Maximum DrawDown: -0.20440675242152695
# Sharpe ratio: 3.280870833780588
# =================================
# =================================
# Initial portfolio value:100000
# Final portfolio value: 41243451392.0
# Final accumulative portfolio value: 412434.51392
# Maximum DrawDown: -0.20243069674719172
# Sharpe ratio: 3.288700985131722
# =================================
# =================================
# Initial portfolio value:100000
# Final portfolio value: 43152715776.0
# Final accumulative portfolio value: 431527.15776
# Maximum DrawDown: -0.2044180564208955
# Sharpe ratio: 3.2962695870363454
# =================================
# =================================
# Initial portfolio value:100000
# Final portfolio value: 44903260160.0
# Final accumulative portfolio value: 449032.6016
# Maximum DrawDown: -0.2029692910794445
# Sharpe ratio: 3.304239219682613
# =================================
# =================================
# Initial portfolio value:100000
# Final portfolio value: 46543552512.0
# Final accumulative portfolio value: 465435.52512
# Maximum DrawDown: -0.2036742961693866
# Sharpe ratio: 3.311325731532019
# =================================
# =================================
# Initial portfolio value:100000
# Final portfolio value: 48173187072.0
# Final accumulative portfolio value: 481731.87072
# Maximum DrawDown: -0.2030114567407918
# Sharpe ratio: 3.318077380081823
# =================================

# %% [markdown]
# ## Teste do modelo
#
# Após o treinamento, será criado um novo ambiente de teste utilizado para a avaliação de sua performance no ano de 2017.

# %%
# Ambiente de teste
environment_test = PortfolioOptimizationEnv(
        test_df,
        initial_amount=100000,
        comission_fee_pct=0,
        time_window=50,
        features=features
    )

# Importação e preparação do modelo treinado
policy = GradientPolicy()
policy.load_state_dict(torch.load("trained_models/policy_EIIE_2017.pt"))
policy = policy.to(device)

# Obtenção das métricas ao longo de 2017
done = False
obs = environment_test.reset()
pvm = PVM(environment_test.episode_length, portfolio_size=len(br_tickers))
while not done:
    last_action = pvm.retrieve()
    obs_batch = np.expand_dims(obs, axis=0)
    last_action_batch = np.expand_dims(last_action, axis=0)
    action = policy(obs_batch, last_action_batch)
    pvm.add(action)
    obs, _, done, _ = environment_test.step(action)

# %% [markdown]
# ## Avaliação dos resultados
#
# Realização de uma análise da performance ao longo de 2017.

# %%
# Importação do módulo responsável por avaliar a performance doo modelo ao longo de seu teste
from quantamental_lib import Backtest

bk = Backtest(test_environment= environment_test, portfolio_vector = pvm)

# %%
# Criação de um DataFrame contendo os retornos da estratégia e dos principais benchmarks (CDI e IBOV)
df = bk.general_cumulative_daily_returns()

# Salva o DataFrame em um arquivo CSV
df.to_csv('results_df/results_2017.csv', index=True)

display(df)
# Out:
#             Cumulative Daily Returns      IBOV       CDI
# 2017-01-04                  1.000000  1.000000  1.000508
# 2017-01-05                  1.016025  1.007826  1.001016
# 2017-01-06                  1.033797  1.001234  1.001524
# 2017-01-09                  1.032114  1.001802  1.002033
# 2017-01-10                  1.054609  1.008817  1.002542
# ...                              ...       ...       ...
# 2017-12-21                  1.496825  1.219909  1.096824
# 2017-12-22                  1.501878  1.220786  1.097115
# 2017-12-26                  1.514516  1.228921  1.097405
# 2017-12-27                  1.510512  1.235172  1.097696
# 2017-12-28                  1.531520  1.240514  1.097987
#
# [236 rows x 3 columns]

# %%
# Avaliação do índice de Sharpe do modelo
sharpe_ratio = bk.sharpe_ratio(risk_free_rate=0)
print('Sharpe Ratio: ', sharpe_ratio)

# Avaliação da taxa de acerto do modelo
hit_ratio = bk.hit_ratio()
print('Hit ratio: ', hit_ratio)
# Out:
# Sharpe Ratio:  1.395926831623433
# Hit ratio:  0.5169491525423728

# %%
# Plotagem dos resultados para facilitar sua comparação
import matplotlib.pyplot as plt

plt.figure(figsize=(12, 6)) 

plt.plot(df['Cumulative Daily Returns'], label='Estratégia', color ='blue')  
plt.plot(df['IBOV'], label='IBOV', color ='orange')  
plt.plot(df['CDI'], label='CDI', color ='green')  

plt.legend()

plt.ylabel('Retorno acumulado')
plt.xlabel('Data')

plt.show()
